# %%
print("hi")
# Out:
# hi

# %%
print("hello everyone")
# Out:
# hello everyone

# %%
print("hello")
# Out:
# hello

# %%
while True:
    print("Hi")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# ...

# %%
print("hello ")
# Out:
# hello

# %%
print("hello \
        world")
# Out:
# hello         world

# %%
print("""    (")....(")
      (   ' o '  )
      (")-(")
      ("""")-("""") """)
# Out:
#     (")....(")
#       (   ' o '  )
#       (")-(")
#       ()-()

# %%
"""    (")....(")
      (   ' o '  )
      (")-(")
      ("""")-("""") """
# Out:
# '    (")....(")\n      (   \' o \'  )\n      (")-(")\n      ()-() '

# %%
print('Python's world')
# Out:
#   File "<ipython-input-11-98b624cce3c5>", line 1
#     print('Python's world')
#                   ^
# SyntaxError: invalid syntax

# %%
print("python's world")
# Out:
# python's world

# %%
print('python\'s world')
# Out:
# python's world

# %%
print("hello\nworld")
# Out:
# hello
# world

# %%
print("hello\aworld")
# Out:
# helloworld

# %%
name = "ishu"
age = 228
marks = 73.786

# %%
print(f" name of the person is {name}, marks is {marks}, age of the person is {age}")
# Out:
#  name of the person is ishu, marks is 73.786, age of the person is 228

# %%
print ("name of the person is %4s, marks is %10.1f, age of the person is %10d"%(name,marks,age))
# Out:
# name of the person is ishu, marks is       73.8, age of the person is        228

# %%
print("hello \")
# Out:
#   File "<ipython-input-26-7e32b33f3581>", line 1
#     print("hello \")
#                     ^
# SyntaxError: EOL while scanning string literal

# %%
if=10
# Out:
#   File "<ipython-input-27-d804dbd42c9d>", line 1
#     if=10
#       ^
# SyntaxError: invalid syntax

# %%
if1=10

# %%
cisco_temp=20

# %%
x=y=10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
x=20

# %%
id(x)
# Out:
# 8791278789616

# %%
y=20

# %%
id(y)
# Out:
# 8791278789616

# %%
del y

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-9063a9f0e032> in <module>
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
5**5
# Out:
# 3125

# %%
10+20
# Out:
# 30

# %%
10-20
# Out:
# -10

# %%
10/2
# Out:
# 5.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
a=10
b=20
a==b
# Out:
# False

# %%
c=10
a==c
# Out:
# True

# %%
c<=a
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a=!b

# %%
10*40
# Out:
# 400

# %%
a=240
b=1

# %%
a | b
# Out:
# 241

# %%
bin(a)
# Out:
# '0b11110000'

# %%
bin(b)
# Out:
# '0b1'

# %%
a&b
# Out:
# 0

# %%
a=1
b=20
a>20
# Out:
# False

# %%
a>20 or 10>9
# Out:
# True

# %%
I
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-bde71cc9b50e> in <module>
# ----> 1 I
#
# NameError: name 'I' is not defined

# %%
10>9 and 20>I
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-a68e1107ce6e> in <module>
# ----> 1 10>9 and 20>I
#
# NameError: name 'I' is not defined

# %%
10<9 and 20>I
# Out:
# False

# %%
10<9
# Out:
# False

# %%
not 10<9
# Out:
# True

# %%
not true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-e1c80afc9194> in <module>
# ----> 1 not true
#
# NameError: name 'true' is not defined

# %%
not True
# Out:
# False

# %%
str1="pythonprogramming"

# %%
"a" in str1
# Out:
# True

# %%
"x" in str1
# Out:
# False

# %%
"x" not in str1
# Out:
# True

# %%
a=10
b=10
a==b
# Out:
# True

# %%
a is b
# Out:
# True

# %%
id(a)
# Out:
# 8791278789296

# %%
id(b)
# Out:
# 8791278789296

# %%
x = 1.5
y = 1.5
x == y
# Out:
# True

# %%
x is y
# Out:
# False

# %%
id(x)
# Out:
# 135800048

# %%
id(y)
# Out:
# 135800208

# %%
a=257
b=257
a == b
# Out:
# True

# %%
a is b
# Out:
# False

# %%
1/2
# Out:
# 0.5

# %%
2/3
# Out:
# 0.6666666666666666

# %%
5/2
# Out:
# 2.5

# %%
3/2
# Out:
# 1.5

# %%
10+10/29*4
# Out:
# 11.379310344827587

# %%
2**-1
# Out:
# 0.5

# %%
7/3
# Out:
# 2.3333333333333335

# %%
7//3
# Out:
# 2

# %%
10>8 and 8>9
# Out:
# False

# %%
10>8>9
# Out:
# False
